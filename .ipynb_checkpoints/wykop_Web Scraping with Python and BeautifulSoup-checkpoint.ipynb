# %%
import pandas as pd
import csv
import requests
from requests import get
from bs4 import BeautifulSoup
from mtranslate import translate
from pprint import pprint
from time import sleep
from time import time
from random import randint
import matplotlib.pyplot as plt

# %% [markdown]
# https://www.dataquest.io/blog/web-scraping-beautifulsoup/

# %%
# Scrape Wykop for all posts with the mention of "smog"

posts = []
votes = []
dates = []
images = []
users = []

start_time = time()
request_count = 0
req_sess = requests.Session()

for page_num in range(1, 163):
# for page_num in enumerate(response): #I believe this method will scrape not just posts but also comments

    response = req_sess.get(f"https://www.wykop.pl/szukaj/wpisy/smog/strona/{page_num}/")

    # Pause the loop
    #sleep(randint(1,3))

    # Monitor the requests
    request_count += 1
    elapsed_time = time() - start_time
    print('Page {}; Request:{}; Frequency: {} requests/s'.format(page_num, request_count, request_count/elapsed_time))

    #clear_output(wait = True)
    # Throw a warning for non-200 status codes
    if response.status_code != 200:
        print('Request: {}; Status code: {}'.format(requests, response.status_code))
        print(response.headers)

    # Break the loop if the number of requests is greater than expected
    #if requests > 10:
    #    print('Number of requests was greater than expected.')
    #    break

    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('li', class_="entry iC")

    for result in results:
        # Error handling
        try:
            post = result.find('div', class_="text").text
            posts.append(post)

            date = result.time['title']
            dates.append(date)

            vote = result.p.b.span.text
            vote = int(vote)
            votes.append(vote)

            user = result.div.b.text
            users.append(user)

            image = result.find('img',class_='block lazy')
            images.append(image)

        except AttributeError as e:
            print(e)
# Out:
# Page 1; Request:1; Frequency: 0.4388279560228747 requests/s
# Page 2; Request:2; Frequency: 0.5027911336560881 requests/s
# Page 3; Request:3; Frequency: 0.5551499173357771 requests/s
# Page 4; Request:4; Frequency: 0.577298626812917 requests/s
# Page 5; Request:5; Frequency: 0.5913816030429045 requests/s
# Page 6; Request:6; Frequency: 0.6159950451778958 requests/s
# Page 7; Request:7; Frequency: 0.636086907464664 requests/s
# Page 8; Request:8; Frequency: 0.6393555567978947 requests/s
# Page 9; Request:9; Frequency: 0.6434712760912688 requests/s
# Page 10; Request:10; Frequency: 0.6514237010370165 requests/s
# Page 11; Request:11; Frequency: 0.6595703070944001 requests/s
# Page 12; Request:12; Frequency: 0.6711702901030253 requests/s
# Page 13; Request:13; Frequency: 0.6800472009995353 requests/s
# Page 14; Request:14; Frequency: 0.6823656803817968 requests/s
# Page 15; Request:15; Frequency: 0.6876509421588772 requests/s
# Page 16; Request:16; Frequency: 0.692901919988246 requests/s
# Page 17; Request:17; Frequency: 0.6961794995552948 requests/s
# Page 18; Request:18; Frequency: 0.7025181531651401 requests/s
# Page 19; Request:19; Frequency: 0.6975042446900642 requests/s
# Page 20; Request:20; Frequency: 0.6991060941281628 requests/s
# Page 21; Request:21; Frequency: 0.617228124109515 requests/s
# Page 22; Request:22; Frequency: 0.6127231097394951 requests/s
# Page 23; Request:23; Frequency: 0.6134569831004794 requests/s
# Page 24; Request:24; Frequency: 0.6140927324944021 requests/s
# Page 25; Request:25; Frequency: 0.6167694197099208 requests/s
# Page 26; Request:26; Frequency: 0.6204774336012974 requests/s
# Page 27; Request:27; Frequency: 0.623694389759592 requests/s
# Page 28; Request:28; Frequency: 0.6269879385696511 requests/s
# Page 29; Request:29; Frequency: 0.628850736226685 requests/s
# Page 30; Request:30; Frequency: 0.6295015233087864 requests/s
# Page 31; Request:31; Frequency: 0.6243266031990389 requests/s
# Page 32; Request:32; Frequency: 0.6247227484058525 requests/s
# Page 33; Request:33; Frequency: 0.6270377470593138 requests/s
# Page 34; Request:34; Frequency: 0.6269086415371553 requests/s
# Page 35; Request:35; Frequency: 0.6291445574175906 requests/s
# Page 36; Request:36; Frequency: 0.6307260944717304 requests/s
# Page 37; Request:37; Frequency: 0.6326188510349205 requests/s
# Page 38; Request:38; Frequency: 0.6320834364854676 requests/s
# Page 39; Request:39; Frequency: 0.6318431986427839 requests/s
# Page 40; Request:40; Frequency: 0.6340638797547669 requests/s
# Page 41; Request:41; Frequency: 0.6241610596726902 requests/s
# Page 42; Request:42; Frequency: 0.6198120212207426 requests/s
# Page 43; Request:43; Frequency: 0.6182573603534219 requests/s
# Page 44; Request:44; Frequency: 0.6183202313720249 requests/s
# Page 45; Request:45; Frequency: 0.6169332076789252 requests/s
# Page 46; Request:46; Frequency: 0.6197997115610764 requests/s
# Page 47; Request:47; Frequency: 0.6223308651690828 requests/s
# Page 48; Request:48; Frequency: 0.6243843977501821 requests/s
# Page 49; Request:49; Frequency: 0.6234629477179029 requests/s
# Page 50; Request:50; Frequency: 0.6262967632865417 requests/s
# Page 51; Request:51; Frequency: 0.6286602280789063 requests/s
# Page 52; Request:52; Frequency: 0.6311951342991942 requests/s
# Page 53; Request:53; Frequency: 0.6307152998426566 requests/s
# Page 54; Request:54; Frequency: 0.6337726225157498 requests/s
# Page 55; Request:55; Frequency: 0.6331759954568997 requests/s
# Page 56; Request:56; Frequency: 0.6353530446283796 requests/s
# Page 57; Request:57; Frequency: 0.6366051820472105 requests/s
# Page 58; Request:58; Frequency: 0.636767137227308 requests/s
# Page 59; Request:59; Frequency: 0.6384605873887428 requests/s
# Page 60; Request:60; Frequency: 0.6409136527155619 requests/s
# Page 61; Request:61; Frequency: 0.6341704720874953 requests/s
# Page 62; Request:62; Frequency: 0.6291628329729508 requests/s
# Page 63; Request:63; Frequency: 0.6301914432123179 requests/s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-02594a8c437b> in <module>
#      35     #    break
#      36
# ---> 37     soup = BeautifulSoup(response.text, 'html.parser')
#      38     results = soup.find_all('li', class_="entry iC")
#      39
#
# ~/.local/share/virtualenvs/hypatia-wv30oaHf/lib/python3.6/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     279             self.reset()
#     280             try:
# --> 281                 self._feed()
#     282                 break
#     283             except ParserRejectedMarkup:
#
# ~/.local/share/virtualenvs/hypatia-wv30oaHf/lib/python3.6/site-packages/bs4/__init__.py in _feed(self)
#     340         self.builder.reset()
#     341
# --> 342         self.builder.feed(self.markup)
#     343         # Close out any unfinished strings and close all the open tags.
#     344         self.endData()
#
# ~/.local/share/virtualenvs/hypatia-wv30oaHf/lib/python3.6/site-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     245         parser.soup = self.soup
#     246         try:
# --> 247             parser.feed(markup)
#     248             parser.close()
#     249         except HTMLParseError as e:
#
# /usr/lib/python3.6/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# /usr/lib/python3.6/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# /usr/lib/python3.6/html/parser.py in parse_starttag(self, i)
#     343             self.handle_startendtag(tag, attrs)
#     344         else:
# --> 345             self.handle_starttag(tag, attrs)
#     346             if tag in self.CDATA_CONTENT_ELEMENTS:
#     347                 self.set_cdata_mode(tag)
#
# ~/.local/share/virtualenvs/hypatia-wv30oaHf/lib/python3.6/site-packages/bs4/builder/_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#      91     def handle_starttag(self, name, attrs, handle_empty_element=True):
#      92         # XXX namespace
# ---> 93         attr_dict = {}
#      94         for key, value in attrs:
#      95             # Change None attribute values to the empty string
#
# KeyboardInterrupt:

# %%
wykopDF1 = pd.DataFrame({'post':posts,
                       'date': dates,
                         'user':users,
                       'vote': votes,
                        'image':images
})
# wykopDF1.to_csv('rawWebScraps_Wykop/wykopRawV2.csv')
print(wykopDF1.info())

wykopDF1.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3092 entries, 0 to 3091
# Data columns (total 5 columns):
# post     3092 non-null object
# date     3092 non-null object
# user     3092 non-null object
# vote     3092 non-null int64
# image    1643 non-null object
# dtypes: int64(1), object(4)
# memory usage: 120.9+ KB
# None
#                                                    post                 date  \
# 3087  \n\n\n            Kurwa dzisiaj wracając zza m...  2017-12-20 18:14:09
# 3088  \n\n\n            Pył zawieszony, wczoraj pona...  2017-12-20 14:04:45
# 3089  \n\n\n            Czemu od wczoraj nie ma dany...  2017-12-20 13:48:46
# 3090  \n\n\n            Chyba pierwszy raz poczułam ...  2017-12-20 13:40:41
# 3091  \n\n\n            #warszawa #smog #fotografia ...  2017-12-20 13:23:11
#
#                   user  vote  \
# 3087            viejra    10
# 3088             Kumin     7
# 3089            bachus     4
# 3090  ansekabanseflore     8
# 3091  C..............o    15
#
#                                                   image
# 3087                                               None
# 3088  <img class="block lazy" data-original="https:/...
# 3089                                               None
# 3090                                               None
# 3091  <img class="block lazy" data-original="https:/...

# %% [markdown]
# ###################################################################################################

# %%
from mtranslate import translate as mtranslate
import re

data = pd.read_csv("rawWebScraps_Wykop/wykopRaw.csv")
data2 = pd.read_csv("rawWebScraps_Wykop/wykopRawMay2019.csv")


del data['Unnamed: 0']
data['post'] = data['post'].str.strip()
data['post'] = data['post'].replace(r'\n', '', regex = True)
data['post'] = data['post'].replace(r'\t', '', regex = True)
del data2['Unnamed: 0']
data2['post'] = data2['post'].str.strip()
data2['post'] = data2['post'].replace(r'\n', '', regex = True)
data2['post'] = data2['post'].replace(r'\t', '', regex = True)
# data['postEn'] = ''
data['date'] = pd.to_datetime(data['date'])
data2['date'] = pd.to_datetime(data2['date'])


data2.tail() #7288
data.tail()  #7287

dataDF = pd.concat([data,data2]).drop_duplicates().reset_index(drop=True)
dataDF = dataDF.sort_values(by = 'date')
dataDF['Month-Year']=dataDF.date.apply(lambda x: str(x)[:7])
dataDF.to_csv('rawWebScraps_Wykop/wykop2012_18.csv')
dataDF.head()
# Out:
#                                                    post                date  \
# 7286  Ci którzy myślą że wieś to krystalicznie czyst... 2012-12-08 20:41:43
# 7285  #sosnowiec Jebany smog, nie zazdroszczę ludzio... 2012-12-09 11:21:41
# 7284  Idzie atom węgla z atomem tlenu na wódkę. Gdzi... 2013-01-12 15:00:24
# 7283  Krakowski Smog - zdjęcie z 1 stycznia 2013 rok... 2013-01-19 22:12:55
# 7282  #krakow #smog Aktualne jednogodzinne stężenia ... 2013-01-24 23:22:08
#
#                                   user  vote image Month-Year
# 7286  M..............................a     5   NaN    2012-12
# 7285                         bohemot44     4   NaN    2012-12
# 7284                   dybligliniaczek     2   NaN    2013-01
# 7283                         d.......0     2   NaN    2013-01
# 7282                            gurken     4   NaN    2013-01

# %% [markdown]
# # Analysis

# %%
dataDF = pd.read_csv("raw/wykop2012_18.csv")
del dataDF['Unnamed: 0']
dataDF['date'] = pd.to_datetime(dataDF['date'])

polair = pd.read_csv("raw/airPoland2017.csv")

# %%
## Filter DF to Jan. 2017
mask = (dataDF['Month-Year'] == '2017-01')
Jan2017 = dataDF.loc[mask]
sum(Jan2017.post.str.len())
Jan2017['Days'] = Jan2017.date.apply(lambda x: str(x)[8:10])
Jan2017['Krakowcount'] = Jan2017.post.str.count('krakow')
Jan2017['Warszawacount'] = Jan2017.post.str.count('warszawa')

krakowCount = Jan2017.resample('D', on='date').sum().reset_index()
WarszawaCount = Jan2017.resample('D', on='date').sum().reset_index()
WarszawaCount
# Jan2017.head()
# Out:
# /home/hypatia/.local/share/virtualenvs/hypatia-wv30oaHf/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/hypatia/.local/share/virtualenvs/hypatia-wv30oaHf/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/hypatia/.local/share/virtualenvs/hypatia-wv30oaHf/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#          date   vote  Krakowcount  Warszawacount
# 0  2017-01-01     15            1              0
# 1  2017-01-02     35            0              0
# 2  2017-01-03    459            4              3
# 3  2017-01-04     32            1              0
# 4  2017-01-05     24            1              1
# 5  2017-01-06    309            4              0
# 6  2017-01-07    439            5              0
# 7  2017-01-08   5744           46             43
# 8  2017-01-09  20736           55             73
# 9  2017-01-10   7000           39             21
# 10 2017-01-11  10131           62             14
# 11 2017-01-12   1544           16              6
# 12 2017-01-13    266            3              1
# 13 2017-01-14    815            4              1
# 14 2017-01-15     58            3              0
# 15 2017-01-16    474            8              1
# 16 2017-01-17   1643            4              4
# 17 2017-01-18    140            2              2
# 18 2017-01-19    509            4              2
# 19 2017-01-20     83            4              0
# 20 2017-01-21   1407           13              0
# 21 2017-01-22     45            3              0
# 22 2017-01-23    135           12              0
# 23 2017-01-24   1107            2              2
# 24 2017-01-25     22            0              0
# 25 2017-01-26     92            3              1
# 26 2017-01-27    472            7              5
# 27 2017-01-28   1425           21              6
# 28 2017-01-29    208           11              4
# 29 2017-01-30    324           31              0
# 30 2017-01-31    530           26              0

# %%
Jan2017_hash_count = pd.DataFrame(Jan2017.post.str.extractall(r'(\#\w+)')[0].value_counts().reset_index().values, columns=["hashtag", "count"])
Jan2017_hash_count = Jan2017_hash_count.sort_index(axis = 0, ascending=True)
Jan2017_hash_count['hashtag'] = Jan2017_hash_count['hashtag'].replace({'#':''}, regex=True)
Jan2017_hash_count.dtypes
Jan2017_hash_count.head()
# Out:
#      hashtag count
# 0       smog  1478
# 1     krakow   325
# 2   heheszki   207
# 3   warszawa   172
# 4  gownowpis   124

# %%
polair = pd.read_csv("raw/airPoland2017.csv") # Source: http://powietrze.gios.gov.pl/pjp/archives
                                                # Index source: https://airnow.gov/index.cfm?action=airnow.international
polair['date'] = pd.to_datetime(polair['date'])

polair = polair.replace(r',', '.', regex = True)
polair.Bulwarowa = polair.Bulwarowa.replace(r' ', 'NaN', regex = True)

polair.Bulwarowa = polair.Bulwarowa.astype(float)
polair.Bujaka = polair.Bujaka.astype(float)
polair['Aleja Krasińskiego'] = polair['Aleja Krasińskiego'].astype(float)



polair.dtypes
polair_d = polair.resample('D', on='date').mean().reset_index()
polair_d['avg'] = polair_d.mean(axis=1)
polair_d
# Out:
#          date   Bulwarowa  Aleja Krasińskiego      Bujaka         avg
# 0  2017-01-01  101.295652          151.434783  141.600000  131.443478
# 1  2017-01-02   65.604167           92.550000   66.912500   75.022222
# 2  2017-01-03   25.554167           41.220833   27.083333   31.286111
# 3  2017-01-04    7.941667           12.416667    8.316667    9.558333
# 4  2017-01-05    8.158333           15.416667   11.054167   11.543056
# 5  2017-01-06   14.612500           35.308333   18.016667   22.645833
# 6  2017-01-07   65.554167          134.583333  119.104167  106.413889
# 7  2017-01-08  107.128571          210.270833  183.858333  167.085913
# 8  2017-01-09  102.308333          177.962500  142.312500  140.861111
# 9  2017-01-10   88.469231          124.029167  129.465217  113.987872
# 10 2017-01-11  195.033333          235.291667  257.255000  229.193333
# 11 2017-01-12   47.683333           62.716667   44.678261   51.692754
# 12 2017-01-13   20.275000           37.637500   18.429167   25.447222
# 13 2017-01-14   16.270833           31.033333   21.773913   23.026027
# 14 2017-01-15   27.762500           46.079167   29.283333   34.375000
# 15 2017-01-16   60.820833           75.816667   41.170833   59.269444
# 16 2017-01-17   73.020833           81.816667   69.350000   74.729167
# 17 2017-01-18   26.512500           34.395833   26.195833   29.034722
# 18 2017-01-19   42.829167           65.412500   65.345833   57.862500
# 19 2017-01-20  106.545833          160.579167  152.800000  139.975000
# 20 2017-01-21   60.408333           88.533333   81.375000   76.772222
# 21 2017-01-22   43.016667           65.229167   47.554167   51.933333
# 22 2017-01-23  117.700000          136.637500  127.970833  127.436111
# 23 2017-01-24   91.491667          104.741667   91.904167   96.045833
# 24 2017-01-25  102.775000          151.200000  113.100000  122.358333
# 25 2017-01-26   73.329167          108.058333   93.433333   91.606944
# 26 2017-01-27  162.645833          200.912500  200.641667  188.066667
# 27 2017-01-28  166.029167          250.550000  232.500000  216.359722
# 28 2017-01-29  146.487500          187.970833  151.179167  161.879167
# 29 2017-01-30  239.845833          256.066667  260.529167  252.147222
# 30 2017-01-31  286.900000          286.900000  357.500000  310.433333

# %%
Jan2017Df = Jan2017.groupby(Jan2017['Days']).count()
Jan2017Df = Jan2017Df['post']

with plt.xkcd():
    
    ax = plt.gca()
    
    Jan2017Df.plot(x='date', y='',kind="bar",figsize=(20,10))
    krakowCount.plot(kind='line',y='Krakowcount',color="green",ax=ax)
    WarszawaCount.plot(kind='line',y='Warszawacount',color="orange",ax=ax)
    polair_d.plot(kind='line',y='avg',color="red",ax=ax)

# %%
start_date = '2017-01-08'
end_date = '2017-01-12'
mask = (Jan2017['date'] >= start_date) & (Jan2017['date'] <= end_date)
Jan2017_filtered = Jan2017.loc[mask]
print(sum(Jan2017_filtered.post.str.len()))
Jan2017_filtered.head()

Jan2017_f_h = pd.DataFrame(Jan2017_filtered.post.str.extractall(r'(\#\w+)')[0].value_counts().reset_index().values, columns=["hashtag", "count"])
Jan2017_f_h = Jan2017_f_h.sort_index(axis = 0, ascending=True)
Jan2017_f_h['hashtag'] = Jan2017_f_h['hashtag'].replace({'#':''}, regex=True)
Jan2017_f_h
# Out:
# 303001
#                           hashtag count
# 0                            smog  1029
# 1                          krakow   161
# 2                        heheszki   141
# 3                        warszawa   138
# 4                       gownowpis    88
# 5                          polska    62
# 6                         neuropa    45
# 7       zanieczyszczeniepowietrza    43
# 8                         wroclaw    41
# 9                        polityka    41
# 10                          slask    39
# 11                 humorobrazkowy    38
# 12                        zdrowie    33
# 13                      powietrze    30
# 14                        pytanie    30
# 15                         rybnik    30
# 16                      4konserwy    24
# 17                       katowice    22
# 18                        gliwice    22
# 19                            pdk    22
# 20                           lodz    21
# 21                    ciekawostki    18
# 22                       ekologia    17
# 23                    kiciochpyta    16
# 24                      bekazpisu    15
# 25                    gorzkiezale    15
# 26                         pogoda    14
# 27                   oswiadczenie    13
# 28                           zima    13
# 29                     dziendobry    12
# ..                            ...   ...
# 552                         smogu     1
# 553       politykaBagatelizowanie     1
# 554                           kot     1
# 555                         astma     1
# 556                   partiarazem     1
# 557                rowerowykrakow     1
# 558                   zdunskawola     1
# 559                libertarianizm     1
# 560                        klimat     1
# 561              dobrazmianapokaż     1
# 562                          akap     1
# 563                         paryz     1
# 564                   tvnwarszawa     1
# 565             mikroreklamaMaska     1
# 566               swiezepowietrze     1
# 567                      interbud     1
# 568                      sztafeta     1
# 569                patologiazewsi     1
# 570          krakowmozesieschowac     1
# 571                           bhp     1
# 572                   chomiczowka     1
# 573          wykresnaszybkopomiar     1
# 574                smogWypadałoby     1
# 575                       podhale     1
# 576                          gory     1
# 577  plangospodarkiniskoemisyjnej     1
# 578                       rysunki     1
# 579       sredniowiecznememypokaż     1
# 580                 storyPodwoził     1
# 581               smutnealeprawda     1
#
# [582 rows x 2 columns]

# %% [markdown]
# ## Images

# %%
import pandas as pd
from IPython.display import Image, HTML

def path_to_image_html(path):
    '''
     This function essentially convert the image url to 
     '<img src="'+ path + '"/>' format. And one can put any
     formatting adjustments to control the height, aspect ratio, size etc.
     within as in the below example. 
    '''

    return '<img src="'+ path + '" style=max-height:124px;"/>'

HTML(dataDF.to_html(escape=False ,formatters=dict(image=path_to_image_html)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>post</th>
#       <th>date</th>
#       <th>user</th>
#       <th>vote</th>
#       <th>image</th>
#       <th>Month-Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>7256</td>
#       <td>41946 - 26 = 41920Ostatni kopiec w Krakowie za...</td>
#       <td>2013-10-07 17:23:26</td>
#       <td>wspodnicyna

# %% [markdown]
# ## Timeseries of posts mentioning 'Smog' from 2012 to 2019

# %%
countDF = dataDF.groupby(dataDF['Month-Year']).count()
countDF = countDF['post']

with plt.xkcd():
    plt.axvspan(47,50, facecolor='skyblue', alpha=0.25)
    plt.axvspan(35,38, facecolor='skyblue', alpha=0.25)
    plt.axvspan(59,62, facecolor='skyblue', alpha=0.25)
    plt.axvspan(71,74, facecolor='skyblue', alpha=0.25)
    plt.axvspan(23,26, facecolor='skyblue', alpha=0.25)        
    plt.axvspan(11,14, facecolor='skyblue', alpha=0.25)        
    plt.axvspan(0,2, facecolor='skyblue', alpha=0.25)
 
    countDF.plot(x='Month-Year', y='',kind="bar",figsize=(20,10))

# %% [markdown]
# ## Word Frequency Analysis

# %%
words = dataDF.post.str.split(expand=True).stack().value_counts()

# %%
from mtranslate import translate

hash_count = pd.DataFrame(dataDF.post.str.extractall(r'(\#\w+)')[0].value_counts().reset_index().values, columns=["hashtag", "count"])
hash_count = hash_count.sort_index(axis = 0, ascending=True)
hash_count['hashtag'] = hash_count['hashtag'].replace({'#':''}, regex=True)
hash_count.dtypes
# hash_count['hashtag'] = mtranslate(hash_count['hashtag'],'en','pl')
hash_count.head()
# Out:
#     hashtag count
# 0      smog  6138
# 1    krakow  1805
# 2  warszawa   708
# 3  heheszki   644
# 4   wroclaw   530

# %%
mtranslate(data.post[5],'en','pl')
# Out:
# 'From September 2022, the use of old stoves will be banned (1st and 2nd emisní třída). If you use an old stove, you should expect a fine of 50,000kc (~ 8,370 PLN) and further consequences (and subsequent fines). Replacing old furnaces has been going on for several years. The government co-finances the exchange of 100,000 kilns, and those who do not have the resources to exchange the old muse, have the option of taking a non-interest loan for this purpose. # Germany #smog #ecology show all +: GothBoyy666, NashBridges +2 others'

# %%
sum(data['post'].str.len())
# Out:
# 2989815

# %%
data['date'] = pd.to_datetime(data['date'])

data.dtypes
data.resample('Y', on='date').count()
# Out:
#             post  date  user  vote  image
# date
# 2012-12-31     2     2     2     2      0
# 2013-12-31   100   100   100   100     37
# 2014-12-31   193   193   193   193     97
# 2015-12-31   570   570   570   570    288
# 2016-12-31   441   441   441   441    231
# 2017-12-31  2951  2951  2951  2951   1516
# 2018-12-31  2330  2330  2330  2330   1218
# 2019-12-31   700   700   700   700    401

# %%
# translation

from IPython.display import clear_output
import numpy as np
from time import sleep
from mtranslate import translate

translation = []

for postPl in range(0,7286):
    
    if data.post.str.len()[postPl] == 99999:
    
        sleep(randint(101,102))
    
    else:
        clear_output(wait=True)
        trans = mtranslate(data.post[postPl],'en','pl')
        translation.append(trans)
    
    print("Current progress: ", np.round(postPl/len(data)*100,2),"%")
    
# %time

# %%
for i,row in data.iterrows():
    
    
    
    print("Current progress: ", np.round(postPl/len(data)*100,2),"%")
    
# %time

# %%
translation

# %% [markdown]
# Show image in dataframe: https://datascience.stackexchange.com/questions/38083/display-images-url-inside-pandas-dataframe
#
# https://stackoverflow.com/questions/37365824/pandas-ipython-notebook-include-and-display-an-image-in-a-dataframe
#
# Vader: https://medium.com/analytics-vidhya/simplifying-social-media-sentiment-analysis-using-vader-in-python-f9e6ec6fc52f
#
# Simple WordCloud: http://kavita-ganesan.com/word-cloud-for-data-scientists/
